# %%
import pyfolio as pf
import pandas as pd
import datetime as dt

daily_returns_rp = pd.Series(pd.read_csv(r'Output/test_rp_daily_returns.csv')['Returns'])
daily_returns_rp.index = pd.to_datetime(pd.read_csv(r'Output\test_rp_daily_returns.csv')['Date'])
#print(daily_returns_rp)
# Out:
# Date
# 2006-02-01    0.001302
# 2006-02-02   -0.005930
# 2006-02-03   -0.004874
# 2006-02-06    0.002093
# 2006-02-07   -0.008110
#                 ...
# 2019-12-25    0.000000
# 2019-12-26    0.001843
# 2019-12-27    0.000443
# 2019-12-30   -0.003010
# 2019-12-31    0.003977
# Name: Returns, Length: 3630, dtype: float64

# %%
daily_sp500 = pd.Series(pd.read_csv(r'Data\SP500_index_daily_returns.csv')['SP_500'])
daily_sp500.index = pd.to_datetime(pd.read_csv(r'Data\SP500_index_daily_returns.csv')['Date'])
daily_sp500 = daily_sp500[daily_returns_rp.index[0]:]
#print(daily_sp500)
# Out:
# Date
# 2006-02-01    0.001859
# 2006-02-02   -0.009061
# 2006-02-03   -0.005359
# 2006-02-06    0.000783
# 2006-02-07   -0.008095
#                 ...
# 2019-12-23    0.000866
# 2019-12-24   -0.000195
# 2019-12-25    0.000000
# 2019-12-26    0.005128
# 2019-12-27    0.000034
# Name: SP_500, Length: 3628, dtype: float64

# %%
pf.create_returns_tear_sheet(daily_returns_rp, benchmark_rets=daily_sp500)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2006-02-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>172</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>13.306%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>504.018%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.999%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.28</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-46.921%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.10</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>11.59</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.212%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.95</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>46.92</td>
#       <td>2007-10-09</td>
#       <td>2009-03-09</td>
#       <td>2010-01-08</td>
#       <td>589</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18.61</td>
#       <td>2011-07-07</td>
#       <td>2011-08-08</td>
#       <td>2012-01-19</td>
#       <td>141</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17.27</td>
#       <td>2018-09-21</td>
#       <td>2018-12-24</td>
#       <td>2019-03-21</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12.73</td>
#       <td>2010-04-23</td>
#       <td>2010-07-02</td>
#       <td>2010-10-05</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>11.37</td>
#       <td>2015-08-17</td>
#       <td>2016-02-11</td>
#       <td>2016-03-17</td>
#       <td>154</td>
#     </tr>
#   </tbody>
# </table>

# %%
daily_returns_frp = pd.Series(pd.read_csv(r'Output/test_frp_daily_returns.csv')['Returns'])
daily_returns_frp.index = pd.to_datetime(pd.read_csv(r'Output\test_frp_daily_returns.csv')['Date'])
#print(daily_returns_frp)
pf.create_returns_tear_sheet(daily_returns_frp, benchmark_rets=daily_sp500)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2006-02-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>172</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>11.713%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>392.677%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.275%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.43</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-27.364%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>11.47</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.75%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>27.36</td>
#       <td>2008-01-09</td>
#       <td>2009-04-24</td>
#       <td>2011-03-09</td>
#       <td>826</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16.85</td>
#       <td>2016-07-05</td>
#       <td>2016-11-10</td>
#       <td>2017-12-06</td>
#       <td>372</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.57</td>
#       <td>2018-01-31</td>
#       <td>2018-12-24</td>
#       <td>2019-03-13</td>
#       <td>291</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>9.90</td>
#       <td>2016-02-25</td>
#       <td>2016-05-18</td>
#       <td>2016-06-27</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9.74</td>
#       <td>2007-07-09</td>
#       <td>2007-08-09</td>
#       <td>2007-10-09</td>
#       <td>67</td>
#     </tr>
#   </tbody>
# </table>

# %%
pf.create_returns_tear_sheet(daily_returns_frp, benchmark_rets=daily_returns_rp)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2006-02-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>172</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>11.686%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>391.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.271%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.43</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-27.364%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>11.48</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.75%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.09</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>27.36</td>
#       <td>2008-01-09</td>
#       <td>2009-04-24</td>
#       <td>2011-03-09</td>
#       <td>826</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16.85</td>
#       <td>2016-07-05</td>
#       <td>2016-11-10</td>
#       <td>2017-12-06</td>
#       <td>372</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.57</td>
#       <td>2018-01-31</td>
#       <td>2018-12-24</td>
#       <td>2019-03-13</td>
#       <td>291</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>9.90</td>
#       <td>2016-02-25</td>
#       <td>2016-05-18</td>
#       <td>2016-06-27</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9.74</td>
#       <td>2007-07-09</td>
#       <td>2007-08-09</td>
#       <td>2007-10-09</td>
#       <td>67</td>
#     </tr>
#   </tbody>
# </table>
