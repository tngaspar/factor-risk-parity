# %%
import pyfolio as pf
import pandas as pd
import datetime as dt

daily_returns_rp = pd.Series(pd.read_csv(r'Output/test_rp_daily_returns.csv')['Returns'])
daily_returns_rp.index = pd.to_datetime(pd.read_csv(r'Output\test_rp_daily_returns.csv')['Date'])
#print(daily_returns_rp)

# %%
daily_sp500 = pd.Series(pd.read_csv(r'Data\SP500_index_daily_returns.csv')['SP_500'])
daily_sp500.index = pd.to_datetime(pd.read_csv(r'Data\SP500_index_daily_returns.csv')['Date'])
daily_sp500 = daily_sp500[daily_returns_rp.index[0]:]
#print(daily_sp500)

# %%
pf.create_returns_tear_sheet(daily_returns_rp, benchmark_rets=daily_sp500)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>49</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>15.264%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>79.825%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>11.743%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-17.707%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.78</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.54</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.42%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.90</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17.71</td>
#       <td>2018-09-21</td>
#       <td>2018-12-24</td>
#       <td>2019-04-01</td>
#       <td>137</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.50</td>
#       <td>2018-01-26</td>
#       <td>2018-02-08</td>
#       <td>2018-07-26</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.01</td>
#       <td>2016-01-01</td>
#       <td>2016-02-11</td>
#       <td>2016-03-03</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.72</td>
#       <td>2019-04-30</td>
#       <td>2019-05-31</td>
#       <td>2019-06-19</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.52</td>
#       <td>2019-07-26</td>
#       <td>2019-08-14</td>
#       <td>2019-09-11</td>
#       <td>34</td>
#     </tr>
#   </tbody>
# </table>

# %%
daily_returns_frp = pd.Series(pd.read_csv(r'Output/test_frp_daily_returns.csv')['Returns'])
daily_returns_frp.index = pd.to_datetime(pd.read_csv(r'Output\test_frp_daily_returns.csv')['Date'])
#print(daily_returns_frp)
pf.create_returns_tear_sheet(daily_returns_frp, benchmark_rets=daily_sp500)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>49</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>18.526%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>101.798%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.565%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-16.529%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.48</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.49</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.43</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.139%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.58</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.53</td>
#       <td>2016-08-01</td>
#       <td>2016-10-27</td>
#       <td>2017-01-31</td>
#       <td>132</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14.55</td>
#       <td>2018-12-12</td>
#       <td>2019-04-17</td>
#       <td>2019-06-07</td>
#       <td>128</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12.83</td>
#       <td>2016-04-06</td>
#       <td>2016-04-29</td>
#       <td>2016-06-30</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12.63</td>
#       <td>2018-01-25</td>
#       <td>2018-02-09</td>
#       <td>2018-03-06</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10.60</td>
#       <td>2019-08-27</td>
#       <td>2019-10-02</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
pf.create_returns_tear_sheet(daily_returns_frp, benchmark_rets=daily_returns_rp)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>49</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>31.557%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>211.171%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>30.077%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.72</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.65</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-43.877%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.56</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.06</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.663%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.67</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>43.88</td>
#       <td>2018-09-27</td>
#       <td>2019-08-15</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18.15</td>
#       <td>2017-02-14</td>
#       <td>2017-06-07</td>
#       <td>2017-09-18</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17.39</td>
#       <td>2016-01-04</td>
#       <td>2016-01-20</td>
#       <td>2016-02-03</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14.43</td>
#       <td>2018-01-23</td>
#       <td>2018-02-08</td>
#       <td>2018-03-06</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10.79</td>
#       <td>2016-09-30</td>
#       <td>2016-11-02</td>
#       <td>2016-11-15</td>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
