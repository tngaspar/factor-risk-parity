# %%
import pyfolio as pf
import pandas as pd
import datetime as dt

daily_returns_rp = pd.Series(pd.read_csv(r'Output\risk_parity_daily_returns.csv')['Returns_RP'])
daily_returns_rp.index = pd.to_datetime(pd.read_csv(r'Output\risk_parity_daily_returns.csv')['Date'])

print(daily_returns_rp)
# Out:
# Date
# 2007-01-01    0.000000
# 2007-01-02    0.000000
# 2007-01-03    0.002123
# 2007-01-04    0.001526
# 2007-01-05   -0.009242
#                 ...
# 2019-12-25    0.000000
# 2019-12-26    0.002408
# 2019-12-27    0.000237
# 2019-12-30   -0.002453
# 2019-12-31    0.003803
# Name: Returns_RP, Length: 3392, dtype: float64

# %%
pf.create_returns_tear_sheet(daily_returns_rp)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2007-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>161</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>12.853%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>409.166%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.375%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.27</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-47.733%</td>
#     </tr>
#     <tr>
# ...
