# %%
import pyfolio as pf
import pandas as pd
import datetime as dt

daily_returns_rp = pd.Series(pd.read_csv(r'Output/test_rp_daily_returns.csv')['Returns'])
daily_returns_rp.index = pd.to_datetime(pd.read_csv(r'Output\test_rp_daily_returns.csv')['Date'])
print(daily_returns_rp)
# Out:
# Date
# 2016-01-01    0.000000
# 2016-01-04   -0.026387
# 2016-01-05   -0.000037
# 2016-01-06   -0.018740
# 2016-01-07   -0.025139
#                 ...
# 2019-12-25    0.000000
# 2019-12-26    0.000314
# 2019-12-27   -0.000527
# 2019-12-30   -0.005141
# 2019-12-31    0.003894
# Name: Returns, Length: 1043, dtype: float64

# %%
daily_sp500 = pd.Series(pd.read_csv(r'Data\SP500_index_daily_returns.csv')['SP_500'])
daily_sp500.index = pd.to_datetime(pd.read_csv(r'Data\SP500_index_daily_returns.csv')['Date'])
print(daily_sp500)
# Out:
# Date
# 2007-01-01    0.000000
# 2007-01-02    0.000000
# 2007-01-03   -0.001199
# 2007-01-04    0.001228
# 2007-01-05   -0.006085
#                 ...
# 2019-12-23    0.000866
# 2019-12-24   -0.000195
# 2019-12-25    0.000000
# 2019-12-26    0.005128
# 2019-12-27    0.000034
# Name: SP_500, Length: 3390, dtype: float64

# %%
pf.create_returns_tear_sheet(daily_returns_rp, benchmark_rets=daily_sp500)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2007-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>161</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>12.696%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>399.229%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.044%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.68</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-18.785%</td>
#     </tr>
#     <tr>
# ...
