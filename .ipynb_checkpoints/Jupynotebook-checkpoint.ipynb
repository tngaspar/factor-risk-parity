# %%
import pyfolio as pf
import pandas as pd
import datetime as dt

daily_returns_rp = pd.Series(pd.read_csv('portfolio_daily_returns.csv')['Returns_RP'])
daily_returns_rp.index = pd.to_datetime(pd.read_csv('portfolio_daily_returns.csv')['Date'])

print(daily_returns_rp)
# Out:
# Date
# 2015-11-30    0.000000
# 2015-12-01    0.007199
# 2015-12-02   -0.011520
# 2015-12-03   -0.020777
# 2015-12-04    0.020829
#                 ...
# 2017-10-24    0.002827
# 2017-10-25   -0.011990
# 2017-10-26   -0.001980
# 2017-10-27    0.009926
# 2017-10-30   -0.007152
# Name: Returns_RP, Length: 501, dtype: float64

# %%
pf.create_returns_tear_sheet(daily_returns_rp)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-11-30</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-10-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>21.735%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>47.848%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.58%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.48</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-14.718%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.32</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.16</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.54</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.09</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.03</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.629%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14.72</td>
#       <td>2015-12-29</td>
#       <td>2016-02-09</td>
#       <td>2016-03-22</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.85</td>
#       <td>2016-06-23</td>
#       <td>2016-06-27</td>
#       <td>2016-07-01</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.06</td>
#       <td>2016-09-07</td>
#       <td>2016-11-04</td>
#       <td>2016-11-17</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.16</td>
#       <td>2015-12-01</td>
#       <td>2015-12-18</td>
#       <td>2015-12-29</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.95</td>
#       <td>2017-06-19</td>
#       <td>2017-07-06</td>
#       <td>2017-07-19</td>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table>

# %%
pf.create_full_tear_sheet(daily_returns_rp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4889f49e66be> in <module>
# ----> 1 pf.create_full_tear_sheet(daily_returns_rp, live_start_date='2016-10-31')
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pyfolio\tears.py in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     178                                      positions, transactions)
#     179
# --> 180     create_returns_tear_sheet(
#     181         returns,
#     182         positions=positions,
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pyfolio\plotting.py in call_w_context(*args, **kwargs)
#      50         if set_context:
#      51             with plotting_context(), axes_style():
# ---> 52                 return func(*args, **kwargs)
#      53         else:
#      54             return func(*args, **kwargs)
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pyfolio\tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     464         returns = utils.clip_returns_to_benchmark(returns, benchmark_rets)
#     465
# --> 466     plotting.show_perf_stats(returns, benchmark_rets,
#     467                              positions=positions,
#     468                              transactions=transactions,
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pyfolio\plotting.py in show_perf_stats(returns, factor_returns, positions, transactions, turnover_denom, live_start_date, bootstrap, header_rows)
#     598     if live_start_date is not None:
#     599         live_start_date = ep.utils.get_utc_timestamp(live_start_date)
# --> 600         returns_is = returns[returns.index < live_start_date]
#     601         returns_oos = returns[returns.index >= live_start_date]
#     602
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\extension.py in wrapper(self, other)
#     127
#     128         op = getattr(self._data, opname)
# --> 129         return op(other)
#     130
#     131     wrapper.__name__ = opname
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimelike.py in wrapper(self, other)
#      72         if isinstance(other, self._recognized_scalars) or other is NaT:
#      73             other = self._scalar_type(other)
# ---> 74             self._check_compatible_with(other)
#      75
#      76             other_i8 = self._unbox_scalar(other)
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py in _check_compatible_with(self, other, setitem)
#     460         if other is NaT:
#     461             return
# --> 462         self._assert_tzawareness_compat(other)
#     463         if setitem:
#     464             # Stricter check for setitem vs comparison methods
#
# c:\users\tiago\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arrays\datetimes.py in _assert_tzawareness_compat(self, other)
#     642         elif self.tz is None:
#     643             if other_tz is not None:
# --> 644                 raise TypeError(
#     645                     "Cannot compare tz-naive and tz-aware datetime-like objects."
#     646                 )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects.
